# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                            "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | kerteh
# City not found. Skipping...
# Processing Record 3 of Set 1 | beringovskiy
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | nanortalik
# Processing Record 8 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | kropotkin
# Processing Record 11 of Set 1 | mukhen
# Processing Record 12 of Set 1 | aswan
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | kaitangata
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | nouadhibou
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | cherskiy
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | provideniya
# Processing Record 25 of Set 1 | kavieng
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | bykovo
# Processing Record 28 of Set 1 | moron
# Processing Record 29 of Set 1 | walvis bay
# Processing Record 30 of Set 1 | salta
# Processing Record 31 of Set 1 | dongsheng
# Processing Record 32 of Set 1 | geraldton
# Processing Record 33 of Set 1 | necochea
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | kamaishi
# Processing Record 38 of Set 1 | moose factory
# Processing Record 39 of Set 1 | norman wells
# Processing Record 40 of Set 1 | przhevalskoye
# Processing Record 41 of Set 1 | san pedro de uraba
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | niimi
# Processing Record 44 of Set 1 | westport
# Processing Record 45 of Set 1 | effingham
# Processing Record 46 of Set 1 | cleethorpes
# Processing Record 47 of Set 1 | fortuna
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | guerrero negro
# Processing Record 50 of Set 1 | gillette
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | koslan
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | talnakh
# Processing Record 6 of Set 2 | roma
# Processing Record 7 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 2 | ancud
# Processing Record 9 of Set 2 | manta
# Processing Record 10 of Set 2 | terekli-mekteb
# Processing Record 11 of Set 2 | semey
# Processing Record 12 of Set 2 | carnarvon
# Processing Record 13 of Set 2 | flinders
# Processing Record 14 of Set 2 | ha giang
# Processing Record 15 of Set 2 | takoradi
# Processing Record 16 of Set 2 | victoria
# Processing Record 17 of Set 2 | kenora
# Processing Record 18 of Set 2 | miles city
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | pangnirtung
# Processing Record 21 of Set 2 | mataura
# Processing Record 22 of Set 2 | lavrentiya
# Processing Record 23 of Set 2 | broome
# Processing Record 24 of Set 2 | rikitea
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | airai
# Processing Record 27 of Set 2 | vila franca do campo
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | urumqi
# Processing Record 30 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 2 | abong mbang
# Processing Record 32 of Set 2 | san ramon
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | kununurra
# Processing Record 38 of Set 2 | bluff
# Processing Record 39 of Set 2 | ostrovnoy
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | esperance
# Processing Record 43 of Set 2 | sidney
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | husavik
# Processing Record 46 of Set 2 | ilebo
# Processing Record 47 of Set 2 | ishigaki
# Processing Record 48 of Set 2 | vaini
# Processing Record 49 of Set 2 | labuhan
# Processing Record 50 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 3 | praia
# Processing Record 2 of Set 3 | jambi
# Processing Record 3 of Set 3 | faya
# Processing Record 4 of Set 3 | zalantun
# Processing Record 5 of Set 3 | pemangkat
# Processing Record 6 of Set 3 | berlin
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | iskateley
# Processing Record 9 of Set 3 | marzuq
# Processing Record 10 of Set 3 | senanga
# Processing Record 11 of Set 3 | meadow lake
# Processing Record 12 of Set 3 | hermanus
# Processing Record 13 of Set 3 | san patricio
# Processing Record 14 of Set 3 | nizhniy baskunchak
# Processing Record 15 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 3 | bredasdorp
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | junin
# Processing Record 19 of Set 3 | namwala
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | cape town
# Processing Record 25 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 3 | touros
# Processing Record 27 of Set 3 | albany
# Processing Record 28 of Set 3 | macaubas
# Processing Record 29 of Set 3 | yenagoa
# Processing Record 30 of Set 3 | csanadpalota
# Processing Record 31 of Set 3 | champerico
# Processing Record 32 of Set 3 | pedernales
# Processing Record 33 of Set 3 | dingle
# Processing Record 34 of Set 3 | dunedin
# Processing Record 35 of Set 3 | fort nelson
# Processing Record 36 of Set 3 | yagodnoye
# Processing Record 37 of Set 3 | uglovskoye
# Processing Record 38 of Set 3 | tuatapere
# Processing Record 39 of Set 3 | copiapo
# Processing Record 40 of Set 3 | upernavik
# Processing Record 41 of Set 3 | waingapu
# Processing Record 42 of Set 3 | sandwick
# Processing Record 43 of Set 3 | ixtapa
# Processing Record 44 of Set 3 | smithers
# Processing Record 45 of Set 3 | bijie
# Processing Record 46 of Set 3 | matara
# Processing Record 47 of Set 3 | los llanos de aridane
# Processing Record 48 of Set 3 | kenai
# Processing Record 49 of Set 3 | ampanihy
# Processing Record 50 of Set 3 | tura
# Processing Record 1 of Set 4 | mehamn
# Processing Record 2 of Set 4 | cidreira
# Processing Record 3 of Set 4 | torbay
# Processing Record 4 of Set 4 | madang
# Processing Record 5 of Set 4 | tripoli
# Processing Record 6 of Set 4 | sirohi
# Processing Record 7 of Set 4 | kahului
# Processing Record 8 of Set 4 | saint george
# Processing Record 9 of Set 4 | illela
# Processing Record 10 of Set 4 | adwa
# Processing Record 11 of Set 4 | ilulissat
# Processing Record 12 of Set 4 | stykkisholmur
# Processing Record 13 of Set 4 | kamenka
# Processing Record 14 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 4 | russell
# Processing Record 16 of Set 4 | poronaysk
# Processing Record 17 of Set 4 | severo-kurilsk
# Processing Record 18 of Set 4 | we
# City not found. Skipping...
# Processing Record 19 of Set 4 | kontagora
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | honningsvag
# Processing Record 22 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | abu dhabi
# Processing Record 24 of Set 4 | bac lieu
# Processing Record 25 of Set 4 | makakilo city
# Processing Record 26 of Set 4 | lompoc
# Processing Record 27 of Set 4 | salumbar
# Processing Record 28 of Set 4 | port blair
# Processing Record 29 of Set 4 | namatanai
# Processing Record 30 of Set 4 | hasaki
# Processing Record 31 of Set 4 | waipawa
# Processing Record 32 of Set 4 | brae
# Processing Record 33 of Set 4 | narsaq
# Processing Record 34 of Set 4 | chuy
# Processing Record 35 of Set 4 | dwarka
# Processing Record 36 of Set 4 | kikwit
# Processing Record 37 of Set 4 | north platte
# Processing Record 38 of Set 4 | constitucion
# Processing Record 39 of Set 4 | yuksekova
# Processing Record 40 of Set 4 | aktau
# Processing Record 41 of Set 4 | san quintin
# Processing Record 42 of Set 4 | sur
# Processing Record 43 of Set 4 | santa maria
# Processing Record 44 of Set 4 | maun
# Processing Record 45 of Set 4 | te anau
# Processing Record 46 of Set 4 | tillabery
# City not found. Skipping...
# Processing Record 47 of Set 4 | canoinhas
# Processing Record 48 of Set 4 | kalmunai
# Processing Record 49 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 50 of Set 4 | betare oya
# Processing Record 1 of Set 5 | flin flon
# Processing Record 2 of Set 5 | shagonar
# Processing Record 3 of Set 5 | hirara
# Processing Record 4 of Set 5 | palmas
# Processing Record 5 of Set 5 | veinticinco de mayo
# Processing Record 6 of Set 5 | hofn
# Processing Record 7 of Set 5 | dois corregos
# Processing Record 8 of Set 5 | rudnya
# Processing Record 9 of Set 5 | iqaluit
# Processing Record 10 of Set 5 | piedras negras
# Processing Record 11 of Set 5 | bentiu
# Processing Record 12 of Set 5 | evensk
# Processing Record 13 of Set 5 | sistranda
# Processing Record 14 of Set 5 | san carlos de bariloche
# Processing Record 15 of Set 5 | el alto
# Processing Record 16 of Set 5 | vanimo
# Processing Record 17 of Set 5 | guarapari
# Processing Record 18 of Set 5 | napier
# Processing Record 19 of Set 5 | lazarev
# Processing Record 20 of Set 5 | pangody
# Processing Record 21 of Set 5 | coahuayana
# Processing Record 22 of Set 5 | saint-marc-des-carrieres
# Processing Record 23 of Set 5 | mount gambier
# Processing Record 24 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 5 | akyab
# Processing Record 26 of Set 5 | lugovoy
# Processing Record 27 of Set 5 | yulara
# Processing Record 28 of Set 5 | antalaha
# Processing Record 29 of Set 5 | nyurba
# Processing Record 30 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 5 | carutapera
# Processing Record 32 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 33 of Set 5 | alofi
# Processing Record 34 of Set 5 | barrow
# Processing Record 35 of Set 5 | kieta
# Processing Record 36 of Set 5 | huilong
# Processing Record 37 of Set 5 | gobabis
# Processing Record 38 of Set 5 | astoria
# Processing Record 39 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 5 | port elizabeth
# Processing Record 41 of Set 5 | kaz
# Processing Record 42 of Set 5 | khanpur
# Processing Record 43 of Set 5 | boende
# Processing Record 44 of Set 5 | ayan
# Processing Record 45 of Set 5 | port lincoln
# Processing Record 46 of Set 5 | le pradet
# Processing Record 47 of Set 5 | adre
# Processing Record 48 of Set 5 | la rioja
# Processing Record 49 of Set 5 | mabaruma
# Processing Record 50 of Set 5 | vilyuysk
# Processing Record 1 of Set 6 | berlevag
# Processing Record 2 of Set 6 | punta umbria
# Processing Record 3 of Set 6 | chernyshevskiy
# Processing Record 4 of Set 6 | nikolskoye
# Processing Record 5 of Set 6 | faanui
# Processing Record 6 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 6 | songjianghe
# Processing Record 8 of Set 6 | cungrea
# Processing Record 9 of Set 6 | businga
# Processing Record 10 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 11 of Set 6 | richards bay
# Processing Record 12 of Set 6 | kaseda
# Processing Record 13 of Set 6 | murmino
# Processing Record 14 of Set 6 | vao
# Processing Record 15 of Set 6 | alekseyevsk
# Processing Record 16 of Set 6 | bambous virieux
# Processing Record 17 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 6 | muli
# Processing Record 19 of Set 6 | nacunday
# City not found. Skipping...
# Processing Record 20 of Set 6 | petropavl
# Processing Record 21 of Set 6 | iskitim
# Processing Record 22 of Set 6 | vila velha
# Processing Record 23 of Set 6 | kolondieba
# Processing Record 24 of Set 6 | unity
# Processing Record 25 of Set 6 | hami
# Processing Record 26 of Set 6 | sept-iles
# Processing Record 27 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 28 of Set 6 | conceicao do araguaia
# Processing Record 29 of Set 6 | la palma
# Processing Record 30 of Set 6 | clyde river
# Processing Record 31 of Set 6 | lasa
# Processing Record 32 of Set 6 | alice springs
# Processing Record 33 of Set 6 | vreed en hoop
# City not found. Skipping...
# Processing Record 34 of Set 6 | manicore
# Processing Record 35 of Set 6 | cabedelo
# Processing Record 36 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 6 | comodoro rivadavia
# Processing Record 38 of Set 6 | east london
# Processing Record 39 of Set 6 | belinskiy
# Processing Record 40 of Set 6 | luan
# Processing Record 41 of Set 6 | san policarpo
# Processing Record 42 of Set 6 | katsuura
# Processing Record 43 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 6 | bayji
# Processing Record 45 of Set 6 | kruglolesskoye
# Processing Record 46 of Set 6 | taltal
# Processing Record 47 of Set 6 | kathu
# Processing Record 48 of Set 6 | mitu
# Processing Record 49 of Set 6 | hit
# Processing Record 50 of Set 6 | sekoma
# Processing Record 1 of Set 7 | salalah
# Processing Record 2 of Set 7 | arman
# Processing Record 3 of Set 7 | huarmey
# Processing Record 4 of Set 7 | vardo
# Processing Record 5 of Set 7 | high level
# Processing Record 6 of Set 7 | meulaboh
# Processing Record 7 of Set 7 | ewa beach
# Processing Record 8 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 7 | teguise
# Processing Record 10 of Set 7 | rivers
# Processing Record 11 of Set 7 | sunland park
# Processing Record 12 of Set 7 | pattukkottai
# Processing Record 13 of Set 7 | kirovskiy
# Processing Record 14 of Set 7 | whyalla
# Processing Record 15 of Set 7 | pisco
# Processing Record 16 of Set 7 | brownwood
# Processing Record 17 of Set 7 | gogrial
# Processing Record 18 of Set 7 | sao filipe
# Processing Record 19 of Set 7 | baiyin
# Processing Record 20 of Set 7 | mecca
# Processing Record 21 of Set 7 | chakia
# Processing Record 22 of Set 7 | kifri
# Processing Record 23 of Set 7 | ambon
# Processing Record 24 of Set 7 | asekeyevo
# Processing Record 25 of Set 7 | caceres
# Processing Record 26 of Set 7 | vestmannaeyjar
# Processing Record 27 of Set 7 | vodnyy
# Processing Record 28 of Set 7 | ostersund
# Processing Record 29 of Set 7 | bonthe
# Processing Record 30 of Set 7 | ulladulla
# Processing Record 31 of Set 7 | tual
# Processing Record 32 of Set 7 | qasigiannguit
# Processing Record 33 of Set 7 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 34 of Set 7 | ust-kut
# Processing Record 35 of Set 7 | san ignacio
# Processing Record 36 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 37 of Set 7 | lagoa
# Processing Record 38 of Set 7 | mandalgovi
# Processing Record 39 of Set 7 | kavaratti
# Processing Record 40 of Set 7 | rio grande
# Processing Record 41 of Set 7 | thompson
# Processing Record 42 of Set 7 | taoudenni
# Processing Record 43 of Set 7 | najran
# Processing Record 44 of Set 7 | parana
# Processing Record 45 of Set 7 | lorengau
# Processing Record 46 of Set 7 | lebu
# Processing Record 47 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 48 of Set 7 | rocha
# Processing Record 49 of Set 7 | ketchikan
# Processing Record 50 of Set 7 | at-bashi
# Processing Record 1 of Set 8 | road town
# Processing Record 2 of Set 8 | dikson
# Processing Record 3 of Set 8 | dustlik
# Processing Record 4 of Set 8 | turukhansk
# Processing Record 5 of Set 8 | yamasaki
# Processing Record 6 of Set 8 | la reforma
# Processing Record 7 of Set 8 | klaksvik
# Processing Record 8 of Set 8 | astana
# Processing Record 9 of Set 8 | kirakira
# Processing Record 10 of Set 8 | ciudad bolivar
# Processing Record 11 of Set 8 | laguna
# Processing Record 12 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 8 | abapo
# Processing Record 14 of Set 8 | coquimbo
# Processing Record 15 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 8 | agirish
# Processing Record 17 of Set 8 | cap malheureux
# Processing Record 18 of Set 8 | codrington
# Processing Record 19 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 20 of Set 8 | lazaro cardenas
# Processing Record 21 of Set 8 | djambala
# Processing Record 22 of Set 8 | bantry
# Processing Record 23 of Set 8 | tacuarembo
# Processing Record 24 of Set 8 | camabatela
# Processing Record 25 of Set 8 | villa rica
# Processing Record 26 of Set 8 | aden
# Processing Record 27 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 8 | galan
# Processing Record 29 of Set 8 | mareeba
# Processing Record 30 of Set 8 | cabra
# Processing Record 31 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 33 of Set 8 | adrar
# Processing Record 34 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 8 | nerchinskiy zavod
# Processing Record 36 of Set 8 | muisne
# Processing Record 37 of Set 8 | san cristobal
# Processing Record 38 of Set 8 | ust-maya
# Processing Record 39 of Set 8 | sao joao da barra
# Processing Record 40 of Set 8 | serov
# Processing Record 41 of Set 8 | penjamo
# Processing Record 42 of Set 8 | rabnita
# City not found. Skipping...
# Processing Record 43 of Set 8 | cortez
# Processing Record 44 of Set 8 | palas
# Processing Record 45 of Set 8 | birjand
# Processing Record 46 of Set 8 | chapais
# Processing Record 47 of Set 8 | somvarpet
# Processing Record 48 of Set 8 | port hardy
# Processing Record 49 of Set 8 | taunggyi
# Processing Record 50 of Set 8 | nome
# Processing Record 1 of Set 9 | palaikastron
# Processing Record 2 of Set 9 | vista hermosa
# Processing Record 3 of Set 9 | kuusamo
# Processing Record 4 of Set 9 | glendive
# Processing Record 5 of Set 9 | mogadishu
# Processing Record 6 of Set 9 | kaura namoda
# Processing Record 7 of Set 9 | stillwater
# Processing Record 8 of Set 9 | ribeira grande
# Processing Record 9 of Set 9 | santa isabel
# Processing Record 10 of Set 9 | gimli
# Processing Record 11 of Set 9 | sokoto
# Processing Record 12 of Set 9 | amberley
# Processing Record 13 of Set 9 | yar-sale
# Processing Record 14 of Set 9 | srednekolymsk
# Processing Record 15 of Set 9 | lingao
# Processing Record 16 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 17 of Set 9 | alta floresta
# Processing Record 18 of Set 9 | lata
# Processing Record 19 of Set 9 | belgaum
# Processing Record 20 of Set 9 | lerwick
# Processing Record 21 of Set 9 | macapa
# Processing Record 22 of Set 9 | zhaodong
# Processing Record 23 of Set 9 | bud
# Processing Record 24 of Set 9 | banda aceh
# Processing Record 25 of Set 9 | grindavik
# Processing Record 26 of Set 9 | capissayan
# Processing Record 27 of Set 9 | itoman
# Processing Record 28 of Set 9 | borba
# Processing Record 29 of Set 9 | mackay
# Processing Record 30 of Set 9 | komsomolskiy
# Processing Record 31 of Set 9 | quatre cocos
# Processing Record 32 of Set 9 | diamantina
# Processing Record 33 of Set 9 | nelson bay
# Processing Record 34 of Set 9 | caucaia
# Processing Record 35 of Set 9 | pevek
# Processing Record 36 of Set 9 | mendi
# Processing Record 37 of Set 9 | sampit
# Processing Record 38 of Set 9 | grand gaube
# Processing Record 39 of Set 9 | souillac
# Processing Record 40 of Set 9 | dzilam gonzalez
# Processing Record 41 of Set 9 | mount pleasant
# Processing Record 42 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 9 | cockburn town
# Processing Record 44 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 45 of Set 9 | avera
# Processing Record 46 of Set 9 | gourcy
# Processing Record 47 of Set 9 | victor harbor
# Processing Record 48 of Set 9 | khandbari
# Processing Record 49 of Set 9 | olafsvik
# Processing Record 50 of Set 9 | oktyabrskiy
# Processing Record 1 of Set 10 | talara
# Processing Record 2 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 3 of Set 10 | khorixas
# Processing Record 4 of Set 10 | tirano
# Processing Record 5 of Set 10 | solnechnyy
# Processing Record 6 of Set 10 | fort saint james
# Processing Record 7 of Set 10 | pachino
# Processing Record 8 of Set 10 | gayny
# Processing Record 9 of Set 10 | yumen
# Processing Record 10 of Set 10 | havelock
# Processing Record 11 of Set 10 | garowe
# Processing Record 12 of Set 10 | kismayo
# Processing Record 13 of Set 10 | tafalla
# Processing Record 14 of Set 10 | zhuhai
# Processing Record 15 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 10 | kushiro
# Processing Record 17 of Set 10 | mizdah
# Processing Record 18 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 19 of Set 10 | deep river
# Processing Record 20 of Set 10 | acajutla
# Processing Record 21 of Set 10 | freeport
# Processing Record 22 of Set 10 | christchurch
# Processing Record 23 of Set 10 | karratha
# Processing Record 24 of Set 10 | opuwo
# Processing Record 25 of Set 10 | louis trichardt
# Processing Record 26 of Set 10 | harur
# Processing Record 27 of Set 10 | krasnoselkup
# Processing Record 28 of Set 10 | pervomayskoye
# Processing Record 29 of Set 10 | nurota
# Processing Record 30 of Set 10 | paamiut
# Processing Record 31 of Set 10 | brunsbuttel
# Processing Record 32 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 10 | gushikawa
# Processing Record 34 of Set 10 | polovinnoye
# Processing Record 35 of Set 10 | hare bay
# Processing Record 36 of Set 10 | valparaiso
# Processing Record 37 of Set 10 | altay
# Processing Record 38 of Set 10 | lamesa
# Processing Record 39 of Set 10 | shaygino
# Processing Record 40 of Set 10 | colesberg
# Processing Record 41 of Set 10 | washington
# Processing Record 42 of Set 10 | kaabong
# Processing Record 43 of Set 10 | sakakah
# Processing Record 44 of Set 10 | lubango
# Processing Record 45 of Set 10 | mazatlan
# Processing Record 46 of Set 10 | havre-saint-pierre
# Processing Record 47 of Set 10 | charters towers
# Processing Record 48 of Set 10 | taitung
# Processing Record 49 of Set 10 | goalpara
# Processing Record 50 of Set 10 | monrovia
# Processing Record 1 of Set 11 | kaeo
# Processing Record 2 of Set 11 | sri aman
# Processing Record 3 of Set 11 | margate
# Processing Record 4 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 5 of Set 11 | khandyga
# Processing Record 6 of Set 11 | nizwa
# Processing Record 7 of Set 11 | luohe
# Processing Record 8 of Set 11 | biloela
# Processing Record 9 of Set 11 | puma
# Processing Record 10 of Set 11 | nouakchott
# Processing Record 11 of Set 11 | willmar
# Processing Record 12 of Set 11 | rudnichnyy
# Processing Record 13 of Set 11 | malinovoye ozero
# Processing Record 14 of Set 11 | horta
# Processing Record 15 of Set 11 | saravan
# Processing Record 16 of Set 11 | pizarro
# Processing Record 17 of Set 11 | egvekinot
# Processing Record 18 of Set 11 | isangel
# Processing Record 19 of Set 11 | suba
# Processing Record 20 of Set 11 | soyo
# Processing Record 21 of Set 11 | ouargaye
# Processing Record 22 of Set 11 | celestun
# Processing Record 23 of Set 11 | curuguaty
# Processing Record 24 of Set 11 | lishan
# Processing Record 25 of Set 11 | sioux lookout
# Processing Record 26 of Set 11 | ambulu
# Processing Record 27 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 11 | thunder bay
# Processing Record 29 of Set 11 | asau
# Processing Record 30 of Set 11 | baykit
# Processing Record 31 of Set 11 | aklavik
# Processing Record 32 of Set 11 | tarko-sale
# Processing Record 33 of Set 11 | rundu
# Processing Record 34 of Set 11 | taksimo
# Processing Record 35 of Set 11 | baoqing
# Processing Record 36 of Set 11 | general roca
# Processing Record 37 of Set 11 | mount isa
# Processing Record 38 of Set 11 | pacific grove
# Processing Record 39 of Set 11 | maltahohe
# Processing Record 40 of Set 11 | krivosheino
# Processing Record 41 of Set 11 | fayaoue
# Processing Record 42 of Set 11 | grass valley
# Processing Record 43 of Set 11 | ossora
# Processing Record 44 of Set 11 | rock springs
# Processing Record 45 of Set 11 | singarayakonda
# Processing Record 46 of Set 11 | medina del campo
# Processing Record 47 of Set 11 | almeirim
# Processing Record 48 of Set 11 | hinundayan
# Processing Record 49 of Set 11 | ust-nera
# Processing Record 50 of Set 11 | zenzeli
# Processing Record 1 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 12 | kurikka
# Processing Record 3 of Set 12 | rehoboth
# Processing Record 4 of Set 12 | bathsheba
# Processing Record 5 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 12 | ormara
# Processing Record 7 of Set 12 | douglas
# Processing Record 8 of Set 12 | arraial do cabo
# Processing Record 9 of Set 12 | tignere
# Processing Record 10 of Set 12 | barra mansa
# Processing Record 11 of Set 12 | graaff-reinet
# Processing Record 12 of Set 12 | safaga
# Processing Record 13 of Set 12 | zhigansk
# Processing Record 14 of Set 12 | goodyear
# Processing Record 15 of Set 12 | vicar
# Processing Record 16 of Set 12 | borzya
# Processing Record 17 of Set 12 | paracuru
# Processing Record 18 of Set 12 | bilma
# Processing Record 19 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 12 | hereford
# Processing Record 21 of Set 12 | yerbogachen
# Processing Record 22 of Set 12 | buala
# Processing Record 23 of Set 12 | okato
# Processing Record 24 of Set 12 | teya
# Processing Record 25 of Set 12 | aykhal
# Processing Record 26 of Set 12 | mweka
# Processing Record 27 of Set 12 | samfya
# Processing Record 28 of Set 12 | tawau
# Processing Record 29 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 12 | mountain home
# Processing Record 31 of Set 12 | jiazi
# Processing Record 32 of Set 12 | poum
# Processing Record 33 of Set 12 | maslovare
# Processing Record 34 of Set 12 | sao paulo de olivenca
# Processing Record 35 of Set 12 | reconquista
# Processing Record 36 of Set 12 | podborany
# Processing Record 37 of Set 12 | kutum
# Processing Record 38 of Set 12 | matamoros
# Processing Record 39 of Set 12 | padang
# Processing Record 40 of Set 12 | arlit
# Processing Record 41 of Set 12 | tchaourou
# Processing Record 42 of Set 12 | harper
# Processing Record 43 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 12 | riyadh
# Processing Record 45 of Set 12 | dakoro
# Processing Record 46 of Set 12 | fairbanks
# Processing Record 47 of Set 12 | beloha
# Processing Record 48 of Set 12 | shelton
# Processing Record 49 of Set 12 | yaroslavl
# Processing Record 50 of Set 12 | matagami
# Processing Record 1 of Set 13 | daru
# Processing Record 2 of Set 13 | half moon bay
# Processing Record 3 of Set 13 | pochutla
# Processing Record 4 of Set 13 | haines junction
# Processing Record 5 of Set 13 | pitimbu
# Processing Record 6 of Set 13 | hay river
# Processing Record 7 of Set 13 | broadstairs
# Processing Record 8 of Set 13 | jackson
# Processing Record 9 of Set 13 | chanika
# Processing Record 10 of Set 13 | kuli
# Processing Record 11 of Set 13 | port victoria
# Processing Record 12 of Set 13 | thai binh
# Processing Record 13 of Set 13 | broken hill
# Processing Record 14 of Set 13 | batamshinskiy
# Processing Record 15 of Set 13 | zheleznodorozhnyy
# Processing Record 16 of Set 13 | yanam
# Processing Record 17 of Set 13 | leningradskiy
# Processing Record 18 of Set 13 | belmonte
# Processing Record 19 of Set 13 | kedrovyy
# Processing Record 20 of Set 13 | andreapol
# Processing Record 21 of Set 13 | ahipara
# Processing Record 22 of Set 13 | la ronge
# Processing Record 23 of Set 13 | kosh-agach
# Processing Record 24 of Set 13 | gladstone
# Processing Record 25 of Set 13 | guozhen
# Processing Record 26 of Set 13 | san lawrenz
# Processing Record 27 of Set 13 | luebo
# Processing Record 28 of Set 13 | biak
# Processing Record 29 of Set 13 | mount darwin
# Processing Record 30 of Set 13 | maningrida
# Processing Record 31 of Set 13 | bandarbeyla
# Processing Record 32 of Set 13 | sao felix do xingu
# Processing Record 33 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 13 | rio gallegos
# Processing Record 35 of Set 13 | beckley
# Processing Record 36 of Set 13 | khovu-aksy
# Processing Record 37 of Set 13 | koungou
# Processing Record 38 of Set 13 | porto walter
# Processing Record 39 of Set 13 | ca mau
# Processing Record 40 of Set 13 | zyryanka
# Processing Record 41 of Set 13 | muros
# Processing Record 42 of Set 13 | maputo
# Processing Record 43 of Set 13 | paita
# Processing Record 44 of Set 13 | never
# Processing Record 45 of Set 13 | balkhash
# Processing Record 46 of Set 13 | mulege
# Processing Record 47 of Set 13 | tilichiki
# Processing Record 48 of Set 13 | clavier
# Processing Record 49 of Set 13 | kalavad
# Processing Record 50 of Set 13 | borogontsy
# Processing Record 1 of Set 14 | inverell
# Processing Record 2 of Set 14 | juliaca
# Processing Record 3 of Set 14 | ares
# Processing Record 4 of Set 14 | piran
# Processing Record 5 of Set 14 | arkhangelsk
# Processing Record 6 of Set 14 | presidencia roque saenz pena
# Processing Record 7 of Set 14 | leh
# Processing Record 8 of Set 14 | olmos
# Processing Record 9 of Set 14 | tias
# Processing Record 10 of Set 14 | anadyr
# Processing Record 11 of Set 14 | onega
# Processing Record 12 of Set 14 | chifeng
# Processing Record 13 of Set 14 | nikolskoye-na-cheremshane
# City not found. Skipping...
# Processing Record 14 of Set 14 | igarka
# Processing Record 15 of Set 14 | ushtobe
# Processing Record 16 of Set 14 | grand forks
# Processing Record 17 of Set 14 | sungaipenuh
# Processing Record 18 of Set 14 | oistins
# Processing Record 19 of Set 14 | eenhana
# Processing Record 20 of Set 14 | angoche
# Processing Record 21 of Set 14 | ocampo
# Processing Record 22 of Set 14 | ayagoz
# Processing Record 23 of Set 14 | pandan
# Processing Record 24 of Set 14 | gamba
# Processing Record 25 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 14 | edd
# Processing Record 27 of Set 14 | tromso
# Processing Record 28 of Set 14 | saint-francois
# Processing Record 29 of Set 14 | pirapemas
# Processing Record 30 of Set 14 | key west
# Processing Record 31 of Set 14 | yuzhnyy
# Processing Record 32 of Set 14 | sukhumi
# Processing Record 33 of Set 14 | racale
# Processing Record 34 of Set 14 | dillon
# Processing Record 35 of Set 14 | tecoanapa
# Processing Record 36 of Set 14 | cuamba
# Processing Record 37 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 14 | juneau
# Processing Record 39 of Set 14 | cao bang
# Processing Record 40 of Set 14 | bakchar
# Processing Record 41 of Set 14 | naze
# Processing Record 42 of Set 14 | katangli
# Processing Record 43 of Set 14 | karonga
# Processing Record 44 of Set 14 | inhambane
# Processing Record 45 of Set 14 | shalya
# Processing Record 46 of Set 14 | ulaanbaatar
# Processing Record 47 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 14 | pemberton
# Processing Record 49 of Set 14 | mildura
# Processing Record 50 of Set 14 | pundaguitan
# Processing Record 1 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 15 | ankang
# Processing Record 3 of Set 15 | scottsboro
# Processing Record 4 of Set 15 | port macquarie
# Processing Record 5 of Set 15 | taywarah
# Processing Record 6 of Set 15 | college
# Processing Record 7 of Set 15 | tshikapa
# Processing Record 8 of Set 15 | oga
# Processing Record 9 of Set 15 | vostok
# Processing Record 10 of Set 15 | manzanillo
# Processing Record 11 of Set 15 | xichang
# Processing Record 12 of Set 15 | ninh binh
# Processing Record 13 of Set 15 | villarrica
# Processing Record 14 of Set 15 | mazagao
# Processing Record 15 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 17 of Set 15 | aguimes
# Processing Record 18 of Set 15 | atar
# Processing Record 19 of Set 15 | bojnurd
# Processing Record 20 of Set 15 | north bend
# Processing Record 21 of Set 15 | wyndham
# Processing Record 22 of Set 15 | ambilobe
# Processing Record 23 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 15 | kosgi
# City not found. Skipping...
# Processing Record 25 of Set 15 | nishihara
# Processing Record 26 of Set 15 | leshan
# Processing Record 27 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 15 | markova
# Processing Record 29 of Set 15 | san fernando
# Processing Record 30 of Set 15 | jishou
# Processing Record 31 of Set 15 | skjaerhollen
# City not found. Skipping...
# Processing Record 32 of Set 15 | sarwar
# Processing Record 33 of Set 15 | nioro
# Processing Record 34 of Set 15 | mopipi
# Processing Record 35 of Set 15 | coihaique
# Processing Record 36 of Set 15 | shumskiy
# Processing Record 37 of Set 15 | rafai
# Processing Record 38 of Set 15 | chihuahua
# Processing Record 39 of Set 15 | tezu
# Processing Record 40 of Set 15 | kharp
# Processing Record 41 of Set 15 | lewisporte
# Processing Record 42 of Set 15 | samarai
# Processing Record 43 of Set 15 | tamiahua
# Processing Record 44 of Set 15 | akranes
# Processing Record 45 of Set 15 | gallup
# Processing Record 46 of Set 15 | lalomanu
# City not found. Skipping...
# Processing Record 47 of Set 15 | timiryazevskiy
# Processing Record 48 of Set 15 | tanete
# Processing Record 49 of Set 15 | bonavista
# Processing Record 50 of Set 15 | gornopravdinsk
# Processing Record 1 of Set 16 | japura
# Processing Record 2 of Set 16 | wajima
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Longyearbyen  78.2186   15.6401     30.04        64          75
# 1   Beringovskiy  63.0500  179.3167     35.98        96         100
# 2        Qaanaaq  77.4840  -69.3632     20.70        69          99
# 3      Busselton -33.6500  115.3333     58.32        69         100
# 4         Atuona  -9.8000 -139.0333     78.46        77          52
# 5     Nanortalik  60.1432  -45.2371     32.32        77          97
# 6      Kropotkin  45.4375   40.5756     55.80        76          98
# 7         Mukhen  48.1000  136.1000     38.88        91           6
# 8          Aswan  24.0934   32.9070    103.30         8           0
# 9  Mar Del Plata -38.0023  -57.5575     61.95        38           0
#
#    Wind Speed Country Current Description
# 0        3.44      SJ       broken clouds
# 1        5.75      RU     overcast clouds
# 2        0.89      GL     overcast clouds
# 3        8.16      AU     overcast clouds
# 4       18.79      PF       broken clouds
# 5        3.76      GL     overcast clouds
# 6        3.49      RU     overcast clouds
# 7        6.78      RU           clear sky
# 8        2.30      EG           clear sky
# 9       12.66      AR           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df= city_data_df[new_column_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0      Longyearbyen      SJ  78.2186   15.6401     30.04        64
# 1      Beringovskiy      RU  63.0500  179.3167     35.98        96
# 2           Qaanaaq      GL  77.4840  -69.3632     20.70        69
# 3         Busselton      AU -33.6500  115.3333     58.32        69
# 4            Atuona      PF  -9.8000 -139.0333     78.46        77
# ..              ...     ...      ...       ...       ...       ...
# 683          Tanete      ID  -3.9443  119.7848     74.68        96
# 684       Bonavista      CA  48.6499  -53.1147     34.84        76
# 685  Gornopravdinsk      RU  60.0500   69.9000     51.58        92
# 686          Japura      ID  -0.3167  102.3500     75.94        96
# 687          Wajima      JP  37.4000  136.9000     56.32        76
#
#      Cloudiness  Wind Speed Current Description
# 0            75        3.44       broken clouds
# 1           100        5.75     overcast clouds
# 2            99        0.89     overcast clouds
# 3           100        8.16     overcast clouds
# 4            52       18.79       broken clouds
# ..          ...         ...                 ...
# 683          97        1.90     overcast clouds
# 684         100        9.31     overcast clouds
# 685         100        3.56     overcast clouds
# 686           3        1.63           clear sky
# 687         100        6.38     overcast clouds
#
# [688 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
